# %% [markdown]
# Importing environment, state process function and DQN solver function

# %%
# environment and DQN solver
from puck_dqn import DQN_agent, puckworld_dqn
from puck_ddqn import DDQN_agent, puckworld_ddqn
from utils import state_process_1, state_process_2, plot_rewards
# Out:
# Using TensorFlow backend.
# pygame 1.9.6
# Hello from the pygame community. https://www.pygame.org/contribute.html
# couldn't import doomish
# Couldn't import doom

# %%
# %load_ext watermark
# %watermark -d -m -v -p numpy,matplotlib,pandas
# Out:
# 2020-03-27
#
# CPython 3.7.6
# IPython 7.12.0
#
# numpy 1.18.1
# matplotlib 3.1.1
# pandas 1.0.0
#
# compiler   : Clang 4.0.1 (tags/RELEASE_401/final)
# system     : Darwin
# release    : 19.4.0
# machine    : x86_64
# processor  : i386
# CPU cores  : 4
# interpreter: 64bit

# %% [markdown]
# ### Puck World Implementation

# %% [markdown]
# Training agent using vanilla DQN

# %%
puckworld_dqn(process_state = state_loc_velocity, display = True, max_iterations = 100)

# %% [markdown]
# Training DDQN agent

# %%
puckworld_ddqn(state_process_1, display = False, max_iterations = 200, 
                   game_size = (15,15), tg_update = 10, memory_min = 30000,
                   memory_max = 1000000, discount = 0.95, epsilon_max = 0.2,
                   epsilon_min = 0.01, learning_rate = 0.001, train_freq=10,
                   epsilon_decay = 0.99995)
# Out:
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /Users/colbywilkinson/Library/Mobile Documents/com~apple~CloudDocs/RL/rl_work/code/puck_ddqn.py:62: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# Run: 1, exploration: 0.2, score: -1.241
# Run: 2, exploration: 0.2, score: -1.22
# Run: 3, exploration: 0.2, score: -1.206
# Run: 4, exploration: 0.2, score: -1.193
# Run: 5, exploration: 0.2, score: -1.261
# Run: 6, exploration: 0.2, score: -1.194
# Run: 7, exploration: 0.2, score: -1.223
# Run: 8, exploration: 0.2, score: -1.254
# Run: 9, exploration: 0.2, score: -1.248
# Run: 10, exploration: 0.2, score: -1.242
# Run: 11, exploration: 0.2, score: -1.263
# Run: 12, exploration: 0.2, score: -1.244
# Run: 13, exploration: 0.2, score: -1.175
# Run: 14, exploration: 0.2, score: -1.243
# Run: 15, exploration: 0.2, score: -1.218
# Run: 16, exploration: 0.2, score: -1.209
# Run: 17, exploration: 0.2, score: -1.234
# Run: 18, exploration: 0.2, score: -1.207
# Run: 19, exploration: 0.2, score: -1.23
# Run: 20, exploration: 0.2, score: -1.199
# Run: 21, exploration: 0.2, score: -1.221
# Run: 22, exploration: 0.2, score: -1.243
# Run: 23, exploration: 0.2, score: -1.26
# Run: 24, exploration: 0.2, score: -1.198
# Run: 25, exploration: 0.2, score: -1.251
# Run: 26, exploration: 0.2, score: -1.217
# Run: 27, exploration: 0.2, score: -1.252
# Run: 28, exploration: 0.2, score: -1.195
# Run: 29, exploration: 0.2, score: -1.257
# Run: 30, exploration: 0.2, score: -1.168
# Run: 31, exploration: 0.2, score: -1.178
# Run: 32, exploration: 0.2, score: -1.19
# Run: 33, exploration: 0.2, score: -1.225
# Run: 34, exploration: 0.2, score: -1.254
# Run: 35, exploration: 0.2, score: -1.209
# Run: 36, exploration: 0.2, score: -1.261
# Run: 37, exploration: 0.2, score: -1.168
# Run: 38, exploration: 0.2, score: -1.246
# Run: 39, exploration: 0.2, score: -1.169
# Run: 40, exploration: 0.2, score: -1.222
# Run: 41, exploration: 0.2, score: -1.234
# Run: 42, exploration: 0.2, score: -1.258
# Run: 43, exploration: 0.2, score: -1.209
# Run: 44, exploration: 0.2, score: -1.21
# Run: 45, exploration: 0.2, score: -1.157
# Run: 46, exploration: 0.2, score: -1.226
# Run: 47, exploration: 0.2, score: -1.217
# Run: 48, exploration: 0.2, score: -1.193
# Run: 49, exploration: 0.2, score: -1.201
# Run: 50, exploration: 0.2, score: -1.25
# Run: 51, exploration: 0.2, score: -1.214
# Run: 52, exploration: 0.2, score: -1.18
# Run: 53, exploration: 0.2, score: -1.158
# Run: 54, exploration: 0.2, score: -1.236
# Run: 55, exploration: 0.2, score: -1.209
# Run: 56, exploration: 0.2, score: -1.208
# Run: 57, exploration: 0.2, score: -1.169
# Run: 58, exploration: 0.2, score: -1.193
# Run: 59, exploration: 0.2, score: -1.171
# Run: 60, exploration: 0.2, score: -1.24
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /Applications/anaconda3/envs/rl/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Run: 61, exploration: 0.161, score: -1.224
# Run: 62, exploration: 0.125, score: -1.223
# Run: 63, exploration: 0.098, score: -1.232
# Run: 64, exploration: 0.076, score: -1.25
# Run: 65, exploration: 0.059, score: -1.256
# Run: 66, exploration: 0.046, score: -1.197
# Run: 67, exploration: 0.036, score: -1.247
# Run: 68, exploration: 0.028, score: -1.256
# Run: 69, exploration: 0.022, score: -1.236
# Run: 70, exploration: 0.017, score: -1.233
# Run: 71, exploration: 0.013, score: -1.201
# Run: 72, exploration: 0.01, score: -1.217
# Run: 73, exploration: 0.01, score: -1.18
# Run: 74, exploration: 0.01, score: -1.18
# Run: 75, exploration: 0.01, score: -1.105
# Run: 76, exploration: 0.01, score: -1.224
# Run: 77, exploration: 0.01, score: -1.202
# Run: 78, exploration: 0.01, score: -1.226
# Run: 79, exploration: 0.01, score: -1.114
# Run: 80, exploration: 0.01, score: -1.227
# Run: 81, exploration: 0.01, score: -1.222
# Run: 82, exploration: 0.01, score: -1.206
# Run: 83, exploration: 0.01, score: -1.183
# Run: 84, exploration: 0.01, score: -1.134
# Run: 85, exploration: 0.01, score: -1.158
# Run: 86, exploration: 0.01, score: -1.168
# Run: 87, exploration: 0.01, score: -1.152
# Run: 88, exploration: 0.01, score: -1.197
# Run: 89, exploration: 0.01, score: -1.169
# Run: 90, exploration: 0.01, score: -1.107
# Run: 91, exploration: 0.01, score: -1.199
# Run: 92, exploration: 0.01, score: -1.19
# Run: 93, exploration: 0.01, score: -1.187
# Run: 94, exploration: 0.01, score: -1.213
# Run: 95, exploration: 0.01, score: -1.252
# Run: 96, exploration: 0.01, score: -1.168
# Run: 97, exploration: 0.01, score: -1.232
# Run: 98, exploration: 0.01, score: -1.191
# Run: 99, exploration: 0.01, score: -1.195
# Run: 100, exploration: 0.01, score: -1.213
# Run: 101, exploration: 0.01, score: -1.194
# Run: 102, exploration: 0.01, score: -1.169
# Run: 103, exploration: 0.01, score: -1.232
# Run: 104, exploration: 0.01, score: -1.251
# Run: 105, exploration: 0.01, score: -1.237
# Run: 106, exploration: 0.01, score: -1.215
# Run: 107, exploration: 0.01, score: -1.213
# Run: 108, exploration: 0.01, score: -1.254
# Run: 109, exploration: 0.01, score: -1.189
# Run: 110, exploration: 0.01, score: -1.196
# Run: 111, exploration: 0.01, score: -1.143
# Run: 112, exploration: 0.01, score: -1.151
# Run: 113, exploration: 0.01, score: -1.172
# Run: 114, exploration: 0.01, score: -1.195
# Run: 115, exploration: 0.01, score: -1.194
# Run: 116, exploration: 0.01, score: -1.199
# Run: 117, exploration: 0.01, score: -1.14
# Run: 118, exploration: 0.01, score: -1.197
# Run: 119, exploration: 0.01, score: -1.208
# Run: 120, exploration: 0.01, score: -1.267
# Run: 121, exploration: 0.01, score: -1.2
# Run: 122, exploration: 0.01, score: -1.219
# Run: 123, exploration: 0.01, score: -1.241
# Run: 124, exploration: 0.01, score: -1.191
# Run: 125, exploration: 0.01, score: -1.186
# Run: 126, exploration: 0.01, score: -1.237
# Run: 127, exploration: 0.01, score: -1.255
# Run: 128, exploration: 0.01, score: -1.163
# Run: 129, exploration: 0.01, score: -1.11
# Run: 130, exploration: 0.01, score: -1.135
# Run: 131, exploration: 0.01, score: -1.196
# Run: 132, exploration: 0.01, score: -1.224
# Run: 133, exploration: 0.01, score: -1.224
# Run: 134, exploration: 0.01, score: -1.109
# Run: 135, exploration: 0.01, score: -1.175
# Run: 136, exploration: 0.01, score: -1.202
# Run: 137, exploration: 0.01, score: -1.239
# Run: 138, exploration: 0.01, score: -1.249
# Run: 139, exploration: 0.01, score: -1.234
# Run: 140, exploration: 0.01, score: -1.194
# Run: 141, exploration: 0.01, score: -1.23
# Run: 142, exploration: 0.01, score: -1.168
# Run: 143, exploration: 0.01, score: -1.211
# Run: 144, exploration: 0.01, score: -1.232
# Run: 145, exploration: 0.01, score: -1.222
# Run: 146, exploration: 0.01, score: -1.229
# Run: 147, exploration: 0.01, score: -1.222
# Run: 148, exploration: 0.01, score: -1.227
# Run: 149, exploration: 0.01, score: -1.23
# Run: 150, exploration: 0.01, score: -1.185
# Run: 151, exploration: 0.01, score: -1.235
# Run: 152, exploration: 0.01, score: -1.188
# Run: 153, exploration: 0.01, score: -1.224
# Run: 154, exploration: 0.01, score: -1.205
# Run: 155, exploration: 0.01, score: -1.133
# Run: 156, exploration: 0.01, score: -1.174
# Run: 157, exploration: 0.01, score: -1.23
# Run: 158, exploration: 0.01, score: -1.263
# Run: 159, exploration: 0.01, score: -1.223
# Run: 160, exploration: 0.01, score: -1.207
# Run: 161, exploration: 0.01, score: -1.222
# Run: 162, exploration: 0.01, score: -1.215
# Run: 163, exploration: 0.01, score: -1.215
# Run: 164, exploration: 0.01, score: -1.223
# Run: 165, exploration: 0.01, score: -1.242
# Run: 166, exploration: 0.01, score: -1.226
# Run: 167, exploration: 0.01, score: -1.139
# Run: 168, exploration: 0.01, score: -1.177
# Run: 169, exploration: 0.01, score: -1.23
# Run: 170, exploration: 0.01, score: -1.165
# Run: 171, exploration: 0.01, score: -1.226
# Run: 172, exploration: 0.01, score: -1.178
# Run: 173, exploration: 0.01, score: -1.174
# Run: 174, exploration: 0.01, score: -1.196
# Run: 175, exploration: 0.01, score: -1.217
# Run: 176, exploration: 0.01, score: -1.206
# Run: 177, exploration: 0.01, score: -1.172
# Run: 178, exploration: 0.01, score: -1.184
# Run: 179, exploration: 0.01, score: -1.161
# Run: 180, exploration: 0.01, score: -1.15
# Run: 181, exploration: 0.01, score: -1.184
# Run: 182, exploration: 0.01, score: -1.219
# Run: 183, exploration: 0.01, score: -1.219
# Run: 184, exploration: 0.01, score: -1.213
# Run: 185, exploration: 0.01, score: -1.212
# Run: 186, exploration: 0.01, score: -1.135
# Run: 187, exploration: 0.01, score: -1.141
# Run: 188, exploration: 0.01, score: -1.147
# Run: 189, exploration: 0.01, score: -1.196
# Run: 190, exploration: 0.01, score: -1.164
# Run: 191, exploration: 0.01, score: -1.197
# Run: 192, exploration: 0.01, score: -1.175
# Run: 193, exploration: 0.01, score: -1.191
# Run: 194, exploration: 0.01, score: -1.217
# Run: 195, exploration: 0.01, score: -1.162
# Run: 196, exploration: 0.01, score: -1.092
# Run: 197, exploration: 0.01, score: -1.112
# Run: 198, exploration: 0.01, score: -1.211
# Run: 199, exploration: 0.01, score: -1.226
# Run: 200, exploration: 0.01, score: -1.224
# End Training

# %% [markdown]
# Plotting rolling average rewards for trained agent

# %%
plot_rewards('./results.csv')
